# %%
import json
from datetime import timedelta
from html import unescape
from html.parser import HTMLParser

import requests

from utils.datetime import duration_to_minutes
from utils.datetime import parse_iso

# %%
JSON_URL = "https://cfp.pydata.org/pydata-amsterdam-2025/schedule/export/schedule.json"  # listed on the Pretalx schedule page
out_schedule = "data/pydata_amsterdam_2025_schedule.json"
out_descriptions = "data/pydata_amsterdam_2025_descriptions.json"
out_speakers_description = "data/pydata_amsterdam_2025_speakers_description.json"

# %%
class _Stripper(HTMLParser):
    def __init__(self):
        super().__init__(convert_charrefs=True)
        self._buf = []
    def handle_data(self, d): self._buf.append(d)
    def get_text(self): return "".join(self._buf)

def strip_html(html: str) -> str:
    if not html:
        return ""
    p = _Stripper()
    p.feed(html)
    return p.get_text().strip()

def normalize_ws(s: str) -> str:
    return " ".join((s or "").split())

# %%
data = requests.get(JSON_URL, timeout=30).json()

# %%
data["schedule"]["conference"]["days"]
# Out:
# [{'index': 1,
#   'date': '2025-09-24',
#   'day_start': '2025-09-24T04:00:00+02:00',
#   'day_end': '2025-09-25T03:59:00+02:00',
#   'rooms': {'Katherine Johnson @ TNW City': [{'guid': 'dffc7442-d29d-594b-8704-c6d2d7a20702',
#      'code': 'BTDWCM',
#      'id': 77812,
#      'logo': None,
#      'date': '2025-09-24T09:00:00+02:00',
#      'start': '09:00',
#      'duration': '01:30',
#      'room': 'Katherine Johnson @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77812-next-level-retrieval-in-rag-techniques-and-tools-for-enhanced-performance',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/BTDWCM/',
#      'title': 'Next-Level Retrieval in RAG: Techniques and Tools for Enhanced Performance',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'Retrieval-Augmented Generation (RAG) systems rely heavily on the quality of the retrieval process to generate accurate and contextually relevant outputs. In this 90-minute tutorial, we explore practical techniques to enhance retrieval across three key stages: pre-retrieval, mid-retrieval, and post-retrieval. Participants will learn how to optimize data preparation, query strategies, reranking, and evaluation to significantly improve the performance of RAG systems. A real-world case study will guide attendees through implementing these methods in a complete retrieval workflow.',
#      'description': "The tutorial provides a structured approach to optimizing retrieval in RAG pipelines. We'll cover:\r\n* Pre-retrieval optimization: how to preprocess and structure data, choose appropriate embeddings, and design efficient indexing and caching mechanisms.\r\n* Mid-retrieval optimization: strategies for query expansion, context-aware reformulation, and reranking retrieved documents for relevance.\r\n* Post-retrieval optimization: methods for refining and filtering results, incorporating user feedback, and continuously evaluating system performance.\r\n\r\nParticipants will explore practical techniques and open-source tools to operationalize enhanced retrieval at each of these stages. We’ll demonstrate the full workflow through a detailed case study, showing how to implement different techniques at each stage to build a more efficient and intelligent retrieval pipeline.\r\n\r\n#### Outline:\r\n* Introduction to Retrieval in RAG Systems\r\n* Case Study Walkthrough: Applying All Stages\r\n  * Pre-Retrieval Optimization\r\n    * Data preprocessing\r\n    * Embedding techniques\r\n    * Indexing strategies\r\n    * Pre-filtering and caching\r\n  * Mid-Retrieval Optimization \r\n    * Query reformulation and expansion\r\n    * Contextual query reframing\r\n    * Recursive summarization frameworks\r\n    * Reranking techniques\r\n    * Distributed retrieval methods\r\n * Post-Retrieval Optimization\r\n    * Result filtering and refinement\r\n    * Contextual relevance using chat history\r\n    * Feedback loops and active learning\r\n    * Evaluation metrics and continuous monitoring\r\n* Q&A and Wrap-up\r\n\r\nBackground Knowledge Required:\r\n* Familiarity with Python\r\n* Basic understanding of LLMs\r\n\r\nTarget Audience: ML engineers, data scientists, developers working with LLMs in production, and anyone looking to learn how to build robust AI workflows using open source tools.",
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'KEHTJF',
#        'name': 'Mahima Arora',
#        'avatar': 'https://cfp.pydata.org/media/avatars/KEHTJF_jx1sWEY.png',
#        'biography': 'Mahima Arora is a Senior Data Scientist on the Data & AI team at Red Hat, specializing in Generative AI applications. She develops AI-powered solutions that enhance efficiency and effectiveness, leading initiatives to optimize AI systems for greater impact. An open-source enthusiast, Mahima continuously explores new tools and technologies to expand her expertise and stay at the forefront of innovation.',
#        'public_name': 'Mahima Arora',
#        'guid': 'fbde50eb-0657-5685-a129-80f78287d373',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/KEHTJF/'},
#       {'code': 'SFVFTF',
#        'name': 'Aarti Jha',
#        'avatar': 'https://cfp.pydata.org/media/avatars/SFVFTF_dAt9cDT.jpg',
#        'biography': 'Aarti Jha is a Senior Data Scientist at Red Hat, where she develops AI-driven solutions to streamline internal processes and reduce operational costs. She brings over 6.5 years of experience in building and deploying data science and machine learning solutions across industry domains. She has been an active part of the PyData community and presented at PyData NYC 2024.',
#        'public_name': 'Aarti Jha',
#        'guid': 'bdb6953a-cbfd-5f15-95a6-2b128c163ad4',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/SFVFTF/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/BTDWCM/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/BTDWCM/',
#      'attachments': []},
#     {'guid': '5e182b8a-b82f-5a34-a265-09ce7ce7f825',
#      'code': '8WVBMB',
#      'id': 79192,
#      'logo': None,
#      'date': '2025-09-24T10:50:00+02:00',
#      'start': '10:50',
#      'duration': '01:30',
#      'room': 'Katherine Johnson @ TNW City',
#      'slug': 'pydata-amsterdam-2025-79192-building-ai-agents-with-observability-tooling-in-pycharm',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/8WVBMB/',
#      'title': 'Building AI Agents With Observability Tooling in PyCharm',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'As AI-powered agents and workflows grow in complexity, understanding their internal behavior becomes critical. In this hands-on workshop, you’ll build an agent and explore how observability tooling in PyCharm can help you trace, inspect, and debug its behavior at every stage – without having to leave the IDE.',
#      'description': 'This workshop introduces a practical workflow for building AI agents using LangGraph, with a focus on observability tooling in PyCharm to manage growing complexity. As the agent’s logic becomes more advanced, we’ll show how tracing and inspection tools help developers understand behavior, diagnose issues, and stay in control of what the agent is doing.\r\nIn this workshop, you will:\r\nBuild AI agents using LangGraph.\r\nUse observability tooling in PyCharm to trace and debug agent behavior.\r\nMake use of your confident Python skills and basic LLM knowledge.',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': '9XAYMQ',
#        'name': 'Yaroslav Sokolov',
#        'avatar': 'https://cfp.pydata.org/media/avatars/9XAYMQ_c2RdTPG.jpeg',
#        'biography': 'Yaroslav Sokolov leads the development of the AI Toolkit at JetBrains. He previously worked as a machine learning engineer, building the local deep learning models behind full line code completion – the main source of AI-powered code suggestions in JetBrains IDEs. His current focus is on building tools that promote best ML practices while remaining intuitive and accessible for developers without a machine learning background.',
#        'public_name': 'Yaroslav Sokolov',
#        'guid': '723f0e22-fde6-577b-9fda-c4e2a3bfab48',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/9XAYMQ/'},
#       {'code': 'TWAWW3',
#        'name': 'Lenar Sharipov',
#        'avatar': 'https://cfp.pydata.org/media/avatars/TWAWW3_yJH1T3i.jpg',
#        'biography': 'Lenar Sharipov is a Tech Lead at JetBrains, working on the AI Toolkit team. He builds tools for PyCharm and other IDEs that help Python developers create AI-powered solutions, such as AI agents. His focus areas include profiling, performance optimization, and improving the developer experience.',
#        'public_name': 'Lenar Sharipov',
#        'guid': '7efd99c3-bc15-5dda-8381-6e5c3936203f',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/TWAWW3/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/8WVBMB/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/8WVBMB/',
#      'attachments': []},
#     {'guid': '3261c935-b420-5faa-9a2d-2deabf08cbd9',
#      'code': 'JDSRL8',
#      'id': 77612,
#      'logo': None,
#      'date': '2025-09-24T13:20:00+02:00',
#      'start': '13:20',
#      'duration': '01:30',
#      'room': 'Katherine Johnson @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77612-bridging-the-gap-building-robust-tool-integrated-llm-applications-with-the-model-context-protocol',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/JDSRL8/',
#      'title': 'Bridging the Gap: Building Robust, Tool-Integrated LLM Applications with the Model Context Protocol',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'Large Language Models (LLMs) are unlocking transformative capabilities — but integrating them into complex, real-world applications remains a major challenge. Simple prompting isn’t enough when dynamic interaction with tools, structured data, and live context is required. This workshop introduces the Model Context Protocol (MCP), an emerging open standard designed to simplify and standardise this integration. Aimed at forward-thinking developers and technologists, this hands-on session will equip participants with practical skills to build intelligent, modular, and extensible LLM-native applications using MCP.',
#      'description': "Dive into the next evolution of LLM application development with the Model Context Protocol. As LLMs become more capable, the need for a consistent way to connect them with external tools and data is increasingly urgent. This interactive workshop explores MCP as a breakthrough approach to building tool-aware, context-rich AI systems.\r\n\r\nWe’ll cover:\r\n- Core Concepts of MCP: Understand MCP's client-server architecture and how it enables structured, contextual reasoning — think of it as “USB-C for AI.” Learn how tools and resources are exposed, discovered, and invoked via the protocol.\r\n- Development Environment Setup: Get hands-on with a modern Python development stack, including FastMCP, Typer, and Streamlit. Configure access to an LLM backend using either the OpenAI API or a local Ollama instance.\r\n- Building MCP Servers & Tools: Learn to expose functions and resources through an MCP server. We’ll walk through a real example — a Wikipedia search-and-summarisation tool — to demonstrate how to define capabilities and serve them in a standards-compliant way.\r\n- Client Development (CLI & Web): Build robust clients using Typer for command-line interfaces and Streamlit for web apps. Learn how to discover server tools, invoke them, and manage stateful interactions.\r\n- LLM-Orchestrated Interactions: Go beyond prompt engineering. See how LLMs can autonomously select and chain tools via MCP to solve complex tasks. We’ll demonstrate orchestration logic that turns LLMs into intelligent agents — not just text predictors.\r\n- Build an AI Research Assistant: Apply your skills by building a working prototype — an AI Research Assistant. This tool will take natural language queries, use an LLM to plan a response, and call MCP tools to search and summarise data in context.\r\n\r\nBy the end of this workshop, participants will have a working understanding of MCP, a functioning toolchain, and a clear roadmap to building next-generation AI applications.\r\n\r\nWho Should Attend:\r\nDevelopers, data scientists, and technical practitioners ready to move beyond basic prompting and explore advanced, structured LLM integration.\r\n\r\nRequirements:\r\nTo get the most from this workshop, attendees should have:\r\n- Python 3.11+ installed\r\n- Docker (recommended for running the MCP server)\r\n- Access to an LLM backend (OpenAI API or local Ollama)\r\n- Basic familiarity with Python and the command line",
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'P98FWZ',
#        'name': 'Adam Hill',
#        'avatar': None,
#        'biography': 'Adam is the Interim Director of Data Science at ComplyAdvantage, where he leads a brilliant team tackling financial crime with advanced analytics, large-scale systems, and the latest in generative and agentic AI.\r\n\r\nBefore that, he spent eight years in the smart cities space at HAL24K, helping governments and infrastructure providers make better decisions with their data. Along the way, he built and led a team of ten data scientists, and helped launch four spin-out ventures—proving that good data science can move the dial in the real world.\r\n\r\nA recovering astrophysicist, Adam spent a decade analysing data from space telescopes in search of new cosmic phenomena. He’s since redirected that curiosity toward Earth-based problems.\r\n\r\nAdam is an active member of the PyData community, the founder of PyData Southampton, and a long-time volunteer with DataKind UK, supporting charities and NGOs with pro-bono data science.',
#        'public_name': 'Adam Hill',
#        'guid': '72714a14-e222-52bb-a36d-2bfaffd60fdf',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/P98FWZ/'},
#       {'code': 'QHXAGQ',
#        'name': 'Shourya Sharma',
#        'avatar': 'https://cfp.pydata.org/media/avatars/QHXAGQ_ieOwHvH.jpeg',
#        'biography': 'I like to build smart AI systems that solve smart business problems.',
#        'public_name': 'Shourya Sharma',
#        'guid': '1fb7903c-f9fd-5823-9cea-144fc4a21f51',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/QHXAGQ/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/JDSRL8/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/JDSRL8/',
#      'attachments': []},
#     {'guid': '53e045d1-ec4b-55e2-ba3a-94614ff66e10',
#      'code': '7HAHPW',
#      'id': 77813,
#      'logo': None,
#      'date': '2025-09-24T15:10:00+02:00',
#      'start': '15:10',
#      'duration': '01:30',
#      'room': 'Katherine Johnson @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77813-event-driven-ai-agent-workflows-with-dapr',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/7HAHPW/',
#      'title': 'Event-Driven AI Agent Workflows with Dapr',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'As AI systems evolve, the need for robust infrastructure increases. Enter Dapr Agents: an open-source framework for creating production-grade AI agent systems. Built on top of the [Dapr](https://github.com/dapr/dapr) framework, Dapr Agents empowers developers to build intelligent agents capable of collaborating in complex workflows - leveraging Large Language Models (LLMs), durable state, built-in observability, and resilient execution patterns. This workshop will walk through the framework’s core components and through practical examples demonstrate how it solves real-world challenges.',
#      'description': "Managing communication, state, and resiliency between distributed systems remains complex - especially when building multi-agent systems that can reason, act, and collaborate using LLMs. Dapr Agents addresses this gap by bringing durability, observability, and event-driven design to AI applications. In this workshop, we will create an event-driven workflow with multiple autonomous agents in Python and explore Dapr Agents' key features.\r\n\r\n**Target Audience**\r\n\r\nEngineers and data scientists who are exploring or working with LLM-based systems and are excited to build intelligent, multi-agent applications. Attendees should have intermediate Python knowledge. Experience with Dapr is not required, but some understanding of distributed systems, LLMs, or async programming will be helpful. We will not explain every concept in depth, but we will provide resources so you can dig deeper on your own as needed.\r\n\r\nHere are the things you should install before the start of this workshop:\r\n\r\n- [Docker](https://docs.docker.com/desktop/) \r\n- Python 3.10 or above\r\n- virtual environment (recommended uv >= 0.4.25)\r\n- [Dapr CLI](https://docs.dapr.io/getting-started/install-dapr-cli/) \r\n\r\n**Takeaways**\r\n\r\nYou’ll learn how to:\r\n\r\n- Build agents using Python and Dapr\r\n- Connect these agents through event-driven pub/sub messaging\r\n- Persist agent state using Dapr’s state management\r\n- Design resilient, reactive multi-agent workflows\r\n- Observe and debug your system\r\n\r\n**Outline**\r\n\r\n- Introduction (20 mins):\r\n\r\n  1. What is Dapr?  \r\n  2. What are LLM Agents?\r\n  3. Introducing Dapr Agents\r\n  4. Workshop overview\r\n\r\n\r\n- Environment setup (5 mins)\r\n\r\n  1. Install dependencies\r\n  2. Clone workshop repo and verify setup\r\n\r\n\r\n- Develop event-driven workflows with multiple autonomous agents (65 mins)\r\n\r\n  1. Create simple agents (exercise)\r\n  2. Orchestrate workflow using different workflow types (exercise)\r\n  3. Run the multi-agent system (exercise)\r\n  4. Recap key learnings & share additional materials and next steps",
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'FDT8DW',
#        'name': 'Dana Arsovska',
#        'avatar': 'https://cfp.pydata.org/media/avatars/FDT8DW_HoRQvWA.jpeg',
#        'biography': 'Dana is a Platform Engineer at Ahold Delhaize, where she works on the technical and organizational challenges of building reliable and scalable data platforms. Her career spans over 8 years, working on cloud infrastructure, platform engineering, and data engineering in various companies. She is especially passionate about data-intensive systems, platform automation, and engineering culture. Beyond her technical expertise, Dana enjoys mentoring and sharing knowledge within the tech community and contributing to open-source.',
#        'public_name': 'Dana Arsovska',
#        'guid': 'd35a9017-41d6-5a8c-aa3b-dc3b333a73ec',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/FDT8DW/'},
#       {'code': 'LRXYAX',
#        'name': 'Marc Duiker',
#        'avatar': 'https://cfp.pydata.org/media/avatars/LRXYAX_Bnyt38y.png',
#        'biography': "Marc is a Sr Developer Advocate at Diagrid and enjoys sharing knowledge on how to build distributed applications. He's one of the Dapr Community Managers, and he loves helping developers to achieve more every day.\r\n\r\nYou might have seen Marc at a developer meetup or conference, since he's a regular speaker and event-organizer in the area of Dapr, Azure cloud, and serverless technologies. From 2019 to 2025 Marc received the Microsoft Azure MVP award for his community contributions.\r\n\r\nIn his spare time, Marc likes to give attention to the creative part of his brain. He likes to create pixel art (check out VSCode Pets), code visuals & music, and create an occasional retro game.",
#        'public_name': 'Marc Duiker',
#        'guid': '8ca4451b-03d2-5ee8-8338-708fb541e469',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/LRXYAX/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/7HAHPW/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/7HAHPW/',
#      'attachments': []}],
#    'Margaret Hamilton @ TNW City': [{'guid': '713fde81-2676-57d5-b88c-7d2f46d82794',
#      'code': 'TXJASY',
#      'id': 77831,
#      'logo': 'https://cfp.pydata.org/media/pydata-amsterdam-2025/submissions/TXJASY/docling_proces_CQbJDBC.png',
#      'date': '2025-09-24T09:00:00+02:00',
#      'start': '09:00',
#      'duration': '01:30',
#      'room': 'Margaret Hamilton @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77831-meet-docling-the-pandas-for-document-ai',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/TXJASY/',
#      'title': 'Meet Docling: The “Pandas” for document AI',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'A workshop session to show you the basics on how to use Docling to enhance document ingestion in your AI workflow.',
#      'description': "With the rapid rise of AI, developers need better ways to transform complex documents into structured data ready for model training and inference. Enter Docling, an open source Python package that's quickly becoming the go-to for document parsing and export. In just a few months, Docling has earned over 25,000 GitHub stars and is already reshaping how developers approach document AI.\r\n\r\nIn this session, you'll get an in-depth introduction to Docling and how it can streamline your AI workflow, and get a chance to walk through a hands on workshop to create your first custom doc ingestion pipeline with Docling. Key features include:\r\n\r\nBroad format support: Easily convert PDFs, DOCX, PPTX, HTML, images, and Markdown into structured Markdown or JSON.\r\n\r\nDeep document understanding: Accurately capture page layouts, reading order, and tables—essential for complex document analysis.\r\n\r\nAI integration: Use the DoclingDocument format with frameworks like LlamaIndex, LangChain, and InstructLab to power RAG, QA, and LLM training.\r\n\r\nOCR support: Extract data from scanned or image-based documents.\r\n\r\nDeveloper friendly CLI: Process documents quickly and consistently with a simple command-line interface.\r\n\r\nThis workshop will require users to have experience with Python programming and LLMs. It will be presented in Jupyter notebook format and will be accessible and runnable in Google collab, ensuring all participants devices will work for the session.",
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'HRNV7T',
#        'name': 'Mingxuan Zhao',
#        'avatar': 'https://cfp.pydata.org/media/avatars/HRNV7T_iOmsk0H.jpeg',
#        'biography': 'Mingxuan Zhao\r\n\r\nOpen-Source Software Developer and Developer Advocate at IBM\r\n\r\nMing Zhao is an open-source developer and Developer Advocate at IBM Research, where he helps IBM leverage open technologies while building impactful tools and growing vibrant open-source communities. He’s passionate about making open tech accessible to all and ensuring developers have the tools they need to succeed in the rapidly developing AI space. Ming now leads community efforts around Docling, IBM’s fastest-growing open-source project, recently welcomed into the LF AI & Data Foundation.',
#        'public_name': 'Mingxuan Zhao',
#        'guid': 'fda9e5e7-5e21-5e51-8f88-54956a25b680',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/HRNV7T/'},
#       {'code': 'E9UEXW',
#        'name': 'Panos Vagenas',
#        'avatar': 'https://cfp.pydata.org/media/avatars/E9UEXW_AmLl9jE.jpeg',
#        'biography': 'AI Engineer at IBM Research, leading development efforts at the intersection of Artificial Intelligence, Information Retrieval, and Data Management.',
#        'public_name': 'Panos Vagenas',
#        'guid': '6238629c-aba5-507e-9ba9-2262e33b5e0b',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/E9UEXW/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/TXJASY/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/TXJASY/',
#      'attachments': []},
#     {'guid': '29c283f9-df06-5958-b6c8-23c91118d581',
#      'code': 'UDDNM7',
#      'id': 77828,
#      'logo': None,
#      'date': '2025-09-24T10:50:00+02:00',
#      'start': '10:50',
#      'duration': '01:30',
#      'room': 'Margaret Hamilton @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77828-understand-your-data-with-knowledge-graphs',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/UDDNM7/',
#      'title': 'Understand your data with Knowledge Graphs',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'Graph databases give the same importance to relationships as they do to data. Knowledge graphs allows you to uncover insights in your data and efficiently explore the relationships in your data.',
#      'description': 'In this hands-on workshop you will learn how graph databases can help you find understand relationships.\r\n\r\nYou will:\r\n- Learn about graph theory, the elements of a graph database, and when a graph database is a good choice for your use case.\r\n- Explore a graph database, learn the basics of the query language Cypher, and use Cypher to read and write data.\r\n- Import your data into graph database.',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'WXCKAN',
#        'name': "Martin O'Hanlon",
#        'avatar': 'https://cfp.pydata.org/media/avatars/WXCKAN_U2YkOi0.png',
#        'biography': 'Martin is an experienced computer science educator and open source software developer.\r\n\r\nMartin creates educational content for Neo4j and supports developers in using graph technology to understand their data.\r\n\r\nAs a child he wanted to be either a Computer Scientist, Astronaut or Snowboard Instructor.',
#        'public_name': "Martin O'Hanlon",
#        'guid': '06c22406-558f-5c07-8ed5-573af3c05cf7',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/WXCKAN/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/UDDNM7/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/UDDNM7/',
#      'attachments': []},
#     {'guid': '42594c1e-2557-540d-8b22-d18f5b490f2b',
#      'code': 'QEATWZ',
#      'id': 77814,
#      'logo': None,
#      'date': '2025-09-24T13:20:00+02:00',
#      'start': '13:20',
#      'duration': '01:30',
#      'room': 'Margaret Hamilton @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77814-grounding-llms-on-solid-knowledge-assessing-and-improving-knowledge-graph-quality-in-graphrag-applications',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/QEATWZ/',
#      'title': 'Grounding LLMs on Solid Knowledge: Assessing and Improving Knowledge Graph Quality in GraphRAG Applications',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': 'Graph-based Retrieval-Augmented Generation (GraphRAG) enhances large language models (LLMs) by grounding their responses in structured knowledge graphs, offering more accurate, domain-specific, and explainable outputs. However, many of the graphs used in these pipelines are automatically generated or loosely assembled, and often lack the semantic structure, consistency, and clarity required for reliable grounding. The result is misleading retrieval, vague or incomplete answers, and hallucinations that are difficult to trace or fix.\r\n\r\nThis hands-on tutorial introduces a practical approach to evaluating and improving knowledge graph quality in GraphRAG applications. We’ll explore common failure patterns, walk through real-world examples, and share a reusable checklist of features that make a graph “AI-ready.” Participants will learn methods for identifying gaps, inconsistencies, and modeling issues that prevent knowledge graphs from effectively supporting LLMs, and apply simple fixes to improve grounding and retrieval performance in their own projects.',
#      'description': 'Graph-based Retrieval-Augmented Generation (GraphRAG) enhances large language models (LLMs) by grounding their responses in structured knowledge graphs, offering more accurate, domain-specific, and explainable outputs. However, many of the graphs used in these pipelines are automatically generated or loosely assembled, and often lack the semantic structure, consistency, and clarity required for reliable grounding. The result is misleading retrieval, vague or incomplete answers, and hallucinations that are difficult to trace or fix.\r\n\r\nThis hands-on tutorial introduces a practical framework for evaluating and improving knowledge graph quality in GraphRAG systems. We combine lecture-based instruction with a coding case study to explore the structural and semantic pitfalls of weak graphs, and demonstrate how to identify and address them.\r\n\r\nBy the end of the tutorial, participants will be able to:\r\n\r\n- Understand the importance of high-quality KGs in GraphRAG systems and their role in grounding LLM outputs.\r\n\r\n- Identify common problems in LLM-generated or lightly modeled graphs.\r\n\r\n- Apply methods and heuristics for KG quality assessment, including validation, error detection, and refinement techniques.\r\n\r\n- Implement strategies to improve graph structure and content for better AI performance.\r\n\r\nFormat & Requirements:\r\n- Lecture + live coding walk-through (Jupyter notebooks in Python)\r\n- Materials will be shared via GitHub\r\n- Prior exposure to RAG or knowledge graphs is helpful, but not required\r\n\r\nTentative Outline (90 mins):\r\n- 0–15 min – Introduction to GraphRAG & role of KGs in grounding\r\n- 15–35 min – Common issues in LLM-generated or low-quality graphs\r\n- 35–60 min – KG quality: assessment and improvement techniques\r\n- 60–85 min – Live coding walkthrough: identify and fix issues in a real-world knowledge graph\r\n- 85–90 min – Wrap-up + Q&A\r\n\r\nThis tutorial is ideal for data scientists, ML engineers, and AI developers looking to build more robust, explainable, and effective GraphRAG systems.',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'NVWDTB',
#        'name': 'Panos Alexopoulos',
#        'avatar': 'https://cfp.pydata.org/media/avatars/NVWDTB_f7MiQ0B.jpeg',
#        'biography': "Panos Alexopoulos is a semantic technologies expert with nearly two decades of experience in knowledge graphs, ontology engineering, and data semantics. As of April 2025, he serves as Lead Semantic Data & AI Solutions at Triply, a semantic data integration company, after nine years as Head of Ontology at Textkernel in Amsterdam, where he led the development of a large cross-lingual knowledge graph in the HR and recruitment domain. \r\n\r\nPanos holds a PhD in Knowledge Engineering and Management from the National Technical University of Athens and he is the author of *Semantic Modeling for Data: Avoiding Pitfalls and Breaking Dilemmas* (O'Reilly, 2020), a practical guide for building high-quality semantic data models. He is also  also a seasoned educator, delivering training programs on topics like knowledge graphs and large language models.",
#        'public_name': 'Panos Alexopoulos',
#        'guid': '976bd9c8-e688-5c99-bbc9-1d762d17cb07',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/NVWDTB/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/QEATWZ/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/QEATWZ/',
#      'attachments': []},
#     {'guid': 'e2482e6b-e71f-596e-ae95-d2c49dcb071c',
#      'code': 'KNBLMD',
#      'id': 77815,
#      'logo': 'https://cfp.pydata.org/media/pydata-amsterdam-2025/submissions/KNBLMD/DSC_8561_1_RyI_RaIIInM.jpg',
#      'date': '2025-09-24T15:10:00+02:00',
#      'start': '15:10',
#      'duration': '01:30',
#      'room': 'Margaret Hamilton @ TNW City',
#      'slug': 'pydata-amsterdam-2025-77815-listen-a-practical-introduction-to-data-sonification',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/KNBLMD/',
#      'title': 'Listen: A Practical Introduction to Data Sonification',
#      'subtitle': '',
#      'track': None,
#      'type': 'Tutorial',
#      'language': 'en',
#      'abstract': "Sonification–using sound to represent data–is a niche technique for exploring complex patterns, expanding the sensory dimensions of data analysis, and discovering musical ideas that are otherwise inaccessible.\r\n\r\nIn this hands-on session, participants will learn the ins and outs of building sonification pipelines through practical examples with data from healthcare and physics. We’ll also cover key software design considerations for creating flexible and expressive systems that map data into sound. Whether you're a developer, data scientist, researcher, educator, or artist, this session will help you listen to your data.",
#      'description': 'This tutorial is aimed at people working with data who are familiar with basic components of music, like pitch, melody, harmony, and rhythm, although the ability to play an instrument is not required. The technical part will rely on common libraries in the Python data analysis stack: Numpy, Pandas, Matplotlib, Streamlit, and HuggingFace.\r\n\r\nThe goal of this tutorial is to introduce you to the challenge of creating generative music that is grounded in, and reflects some underlying data structure–whether temporal, spatial, or statistical–while remaining musically coherent and expressive. \r\n\r\nWe’ll cover a number of methods, from straightforward rule-based systems to billion-parameter transformer models, highlighting the tradeoffs between control, complexity, and creative potential across different approaches.\r\n\r\nDuring the tutorial you’ll get access to relevant data, and a repository containing end-to-end code examples, including a sonification of healthcare data (ECG signals) and a chaotic physical system (the double pendulum). Using those examples, we’ll explore multiple sonification strategies that can be applied, and multiple aesthetic choices that need to be considered when writing sonification software.\r\n\r\n## Outline\r\n\r\n1. A brief history of sound, music, and algorithms. (10m)\r\n2. Becoming one with the data – exploring datasets with all your senses. (15m)\r\n3. The piano keyboard – absolute minimum of music theory for data scientists. (10m)\r\n4. Finding beauty in the dissonance – sonification of chaotic motion of the double pendulum. Step-by-step walk through. (20m)\r\n5. Extra beat – sonification of ECG data acquired from patients with various types of arrhythmia. Step-by-step walk through. (20m) \r\n6. Team work – exploring ideas together with the audience. (15m) \r\n\r\nIf you want to experiment with your own sonification ideas during the tutorial (which is encouraged), please bring headphones! 🎧',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'QQJBMR',
#        'name': 'Tomek Roszczynialski',
#        'avatar': 'https://cfp.pydata.org/media/avatars/QQJBMR_0VY65Bj.png',
#        'biography': 'Tomek is a data scientist and machine learning developer with a background in, and a passion for, physics. \r\n\r\nHe has been involved in multiple data-heavy projects, from setting up signal processing pipelines handling data from thousands of cardiology patients to building industrial automation software in Polish cement plants. \r\n\r\nIn his spare time, Tomek trains multi-billion-parameter transformer models to play progressive piano music.',
#        'public_name': 'Tomek Roszczynialski',
#        'guid': 'c7f1e2e1-0279-5b6a-99f9-5e259fe330f7',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/QQJBMR/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/KNBLMD/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/KNBLMD/',
#      'attachments': []}]}},
#  {'index': 2,
#   'date': '2025-09-25',
#   'day_start': '2025-09-25T04:00:00+02:00',
#   'day_end': '2025-09-26T03:59:00+02:00',
#   'rooms': {'Apollo': [{'guid': '37eda411-b331-530d-a77d-49a4fb2b4c07',
#      'code': 'CRRXUP',
#      'id': 77051,
#      'logo': None,
#      'date': '2025-09-25T09:00:00+02:00',
#      'start': '09:00',
#      'duration': '00:30',
#      'room': 'Apollo',
#      'slug': 'pydata-amsterdam-2025-77051-opening-notes',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/CRRXUP/',
#      'title': 'Opening notes',
#      'subtitle': '',
#      'track': None,
#      'type': 'Opening notes',
#      'language': 'en',
#      'abstract': 'Opening notes',
#      'description': 'Opening notes',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/CRRXUP/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/CRRXUP/',
#      'attachments': []},
#     {'guid': '5382ea5b-51ec-5d66-a388-98ca95f232fb',
#      'code': 'GMSVMT',
#      'id': 77528,
#      'logo': None,
#      'date': '2025-09-25T09:30:00+02:00',
#      'start': '09:30',
#      'duration': '00:50',
#      'room': 'Apollo',
#      'slug': 'pydata-amsterdam-2025-77528-the-agentification-of-software-has-a-ux-problem',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/GMSVMT/',
#      'title': 'The agentification of software (has a UX problem)',
#      'subtitle': '',
#      'track': None,
#      'type': 'Keynote',
#      'language': 'en',
#      'abstract': 'The "agentification" of software promises a future where we simply tell a machine what we want, and it handles the rest. We have all felt that magic when vibe coding. So why can\'t every interaction with machines be that magical? \r\n\r\nWell, what if the dominant chat-based interface is a dead end? \r\n\r\nThis talk explores the significant UX challenges of agentification. We’ll discuss why chat is an over-promising and under-delivering medium, and how we\'re losing the rich, high-bandwidth context of human communication.',
#      'description': '.',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'LDZLDG',
#        'name': 'Demetrios Brinkmann',
#        'avatar': 'https://cfp.pydata.org/media/avatars/LDZLDG_HglnOu4.jpeg',
#        'biography': 'Demetrios is the founder of the largest community dealing with productionizing AI and ML models. Since April 2020 he has been leading the @MLOps community where more than 75k ML practitioners come together to learn and share experiences, bringing clarity around the operational side of Machine Learning.',
#        'public_name': 'Demetrios Brinkmann',
#        'guid': '9d4de83b-b9ec-5e5f-a493-c1f2a121fea5',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/LDZLDG/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/GMSVMT/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/GMSVMT/',
#      'attachments': []},
#     {'guid': '51183529-5f18-53db-b99c-a0543730d36f',
#      'code': '9UDSCY',
#      'id': 77873,
#      'logo': 'https://cfp.pydata.org/media/pydata-amsterdam-2025/submissions/9UDSCY/us_cloud_9YAoW_vkaRXJU.jpg',
#      'date': '2025-09-25T10:35:00+02:00',
#      'start': '10:35',
#      'duration': '00:35',
#      'room': 'Apollo',
#      'slug': 'pydata-amsterdam-2025-77873-should-captain-america-still-host-your-data-a-call-for-open-eu-based-data-platforms',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/9UDSCY/',
#      'title': 'Should Captain America Still Host Your Data?  A Call for Open, EU-Based Data Platforms.',
#      'subtitle': '',
#      'track': None,
#      'type': 'Talk',
#      'language': 'en',
#      'abstract': 'When you store data in the cloud, do you know who really controls it? In an era of increasing geopolitical tension and growing awareness around digital sovereignty, Dutch research institutes have already begun repatriating sensitive data from US servers to Dutch-controlled storage. This talk explores the hidden risks behind common cloud choices, from legal access by foreign governments to the ethical implications of supporting politically active tech giants. We’ll look at what it means to own your data, how regional storage might not be enough, and what it takes to build an EU-hosted, open-source data platform stack. If you’re a data engineer, architect, or technology leader who cares about privacy, control, and sustainable infrastructure, this talk will equip you with the insight—and motivation—to make different choices.',
#      'description': 'Cloud infrastructure is a foundational part of modern data platforms—but are we fully aware of the trade-offs we make when choosing a provider? This talk makes the case that using US-based cloud services may no longer be a safe or ethical default for organizations operating in Europe. It aims to shift the mindset from convenience to sovereignty, from reliance to control.\r\nThe talk will consist of five parts:\r\n\r\n1. What Is a Data Platform and How Did We Get Here?\r\n2. The Status Quo: What Do Companies Use Today?\r\n3. Why You Should Be Concerned\r\n4. What Are the Alternatives and What Do We Really Need?\r\n5. Call to Action: Join the Movement\r\n\r\n\r\nThis talk is targeted at data engineers, architects, and technically-minded decision-makers. No prior knowledge of specific tools is required—just an interest in the future of cloud data infrastructure and a willingness to challenge the status quo.',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'LTZBCK',
#        'name': 'Manuel Spierenburg',
#        'avatar': 'https://cfp.pydata.org/media/avatars/LTZBCK_JNrKCrf.jpg',
#        'biography': "Manuel Spierenburg is a Data Engineer with a background in software engineering and data science. He's worked with many different languages and tools across various industries, making him a Swiss army knife in the data world. He delivers pragmatic and elegant solutions that create real impact.\r\n\r\nWhen Manuel isn't crunching numbers, he's spending time with his family, including his two kids, or learning new tricks on a skateboard.",
#        'public_name': 'Manuel Spierenburg',
#        'guid': '78cf1d83-55ac-5c62-b67f-253df417e599',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/LTZBCK/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/9UDSCY/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/9UDSCY/',
#      'attachments': []},
#     {'guid': '17878612-950e-5613-83b5-228046443ae3',
#      'code': 'LLGBC9',
#      'id': 77624,
#      'logo': None,
#      'date': '2025-09-25T11:20:00+02:00',
#      'start': '11:20',
#      'duration': '00:35',
#      'room': 'Apollo',
#      'slug': 'pydata-amsterdam-2025-77624-counting-groceries-with-computer-vision-how-picnic-tracks-inventory-automatically',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/LLGBC9/',
#      'title': 'Counting Groceries with Computer Vision: How Picnic Tracks Inventory Automatically',
#      'subtitle': '',
#      'track': None,
#      'type': 'Talk',
#      'language': 'en',
#      'abstract': 'In this talk, we\'ll share how we\'re using computer vision to automate stock counting, right on the conveyor belt. We\'ll discuss the challenges we\'ve faced with the hardware, software, and GenAI components, and we\'ll also review our own benchmark results for the various state-of-the-art models. Finally, we\'ll cover the practical aspects of GenAI deployment, including prompt optimization, preventing LLM "yapping," and creating a robust feedback loop for continuous improvement.',
#      'description': "At Picnic, we deliver groceries to customers across three countries. To ensure we deliver what we promise, we rely on precise stock tracking. But with millions of items moving through our highly automated fulfillment center in Utrecht every day, manually counting stock is incredibly labor-intensive.\r\n\r\nIn this talk, we'll share how we're using computer vision to automate stock counting, right on the conveyor belt. From capturing high-quality images of moving products to evaluating and deploying state-of-the-art models, this project challenged us across the stack: hardware, software, and GenAI.\r\n\r\nWe'll explore topics such as:\r\n* Why YOLO didn't work for us\r\n* Benchmarking the latest (GenAI) vision models\r\n* Optimizing prompts with DSPy\r\n* Preventing unnecessary LLM “yapping”\r\n* Capturing high-quality images of items in motion\r\n\r\nThis session blends practical engineering insights with cutting-edge AI tools making it interesting for anyone applying computer vision to real-world problems.",
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'KK9DKJ',
#        'name': 'Sven Arends',
#        'avatar': 'https://cfp.pydata.org/media/avatars/KK9DKJ_ntw2Ps6.jpeg',
#        'biography': 'Sven Arends is a Senior Machine Learning Engineer at Picnic, where he is currently developing novel LLM applications. With a strong background in machine learning and software engineering, Sven has contributed to a wide range of projects: from predicting delivery times to forecasting buying behaviour and implementing MLOps tooling within Kubernetes. He holds a Master’s degree in Computer Science.\r\n\r\nIn his free time, Sven enjoys creating small embedded devices or visiting the sauna: a tradition he adopted during his time in Finland.',
#        'public_name': 'Sven Arends',
#        'guid': '6d06eb1d-f310-55e0-878b-a4e729ec1752',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/KK9DKJ/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/LLGBC9/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/LLGBC9/',
#      'attachments': []},
#     {'guid': '146a2e43-f8ff-55fb-a7d4-b98f6b855c9c',
#      'code': 'MYXUBZ',
#      'id': 78211,
#      'logo': None,
#      'date': '2025-09-25T12:05:00+02:00',
#      'start': '12:05',
#      'duration': '00:35',
#      'room': 'Apollo',
#      'slug': 'pydata-amsterdam-2025-78211-genai-governance-in-practice-patterns-pitfalls-strategies-across-tools-and-industries',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/MYXUBZ/',
#      'title': 'GenAI governance in practice: patterns, pitfalls & strategies across tools and industries',
#      'subtitle': '',
#      'track': None,
#      'type': 'Talk',
#      'language': 'en',
#      'abstract': 'Governing generative AI systems presents unique challenges, particularly for teams dealing with diverse GenAI subdomains and rapidly changing technological landscapes. In this talk, Maarten de Ruiter, Data Scientist at Xomnia, shares practical insights drawn from real-world GenAI use-cases. He will highlight essential governance patterns, address common pitfalls, and provide actionable strategies for teams utilizing both open-source tools and commercial solutions. Attendees will gain concrete recommendations that work in practice, informed by successes (and failures!) across multiple industries',
#      'description': 'This session offers a practical guide to GenAI governance for teams building with modern data tooling and managing complex, unstructured data pipelines. Drawing from Xomnia’s experience across various GenAI subdomains, Maarten will discuss:\r\n\r\nFrameworks for structuring governance across core GenAI use cases, such as LLM integration, data pipelines, prompt management, and monitoring.\r\n\r\n- A candid look at tool selection: comparing open-source options and commercial solutions, with suggestions for effective combinations that suit real-world needs.\r\n- Techniques for managing unstructured data quality and AI risk, illustrated with code examples, architecture diagrams, and implementation tips.\r\n- Application of the “GenAI Governance Maturity Matrix” to assess and elevate your team’s practices, with field-tested recommendations drawn from real client use cases.\r\n\r\nExpect examples of both what has worked well and what hasn’t, plus the actionable takeaways we wish we’d had from the start. Bring your GenAI governance questions and headaches; the session includes time for troubleshooting and sharing of practical solutions.',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'FHAWPD',
#        'name': 'Maarten de Ruiter',
#        'avatar': 'https://cfp.pydata.org/media/avatars/FHAWPD_WZhruRJ.jpg',
# ...
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'YGQH39',
#        'name': 'Rodrigo Loredo',
#        'avatar': 'https://cfp.pydata.org/media/avatars/YGQH39_virPV9t.jpeg',
#        'biography': "With over 8 years of experience working with data, I've explored various roles. Currently, I work as a Lead Analytics Engineer at Vinted's Data Platform team, where we build and maintain tooling that supports over 200 data professionals in creating and orchestrating data products.\r\nMy linguistics background helps me connect technical precision with clear concepts and drive impactful solutions.",
#        'public_name': 'Rodrigo Loredo',
#        'guid': '1bc3d363-3130-5d8f-bc2c-3019f7f93c6c',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/YGQH39/'},
#       {'code': 'FWEWYJ',
#        'name': 'Oscar Ligthart',
#        'avatar': 'https://cfp.pydata.org/media/avatars/FWEWYJ_qBGhdfC.png',
#        'biography': 'I am a technical lead within the data platform team at Vinted, building tooling to empower our users to create data products. With over 6 years of experience in software engineering, I am passionate about automating pipelines within the world of data.',
#        'public_name': 'Oscar Ligthart',
#        'guid': '3b834c79-a16f-51b6-8a71-67de91d993e7',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/FWEWYJ/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/LSEBQ9/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/LSEBQ9/',
#      'attachments': []},
#     {'guid': '87570f47-6d45-5c2f-bc66-32e614cf0252',
#      'code': 'UK7LSY',
#      'id': 77763,
#      'logo': None,
#      'date': '2025-09-26T14:55:00+02:00',
#      'start': '14:55',
#      'duration': '00:35',
#      'room': 'Nebula',
#      'slug': 'pydata-amsterdam-2025-77763-resource-monitoring-and-optimization-with-metaflow',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/UK7LSY/',
#      'title': 'Resource Monitoring and Optimization with Metaflow',
#      'subtitle': '',
#      'track': None,
#      'type': 'Talk',
#      'language': 'en',
#      'abstract': 'Metaflow is a powerful workflow management framework for data science, but optimizing its cloud resource usage still involves guesswork. We have extended Metaflow with a lightweight resource tracking tool that automatically monitors CPU, memory, GPU, and more, then recommends the most cost-effective cloud instance type for future runs. A single line of code can save you from overprovisioned costs or painful job failures!',
#      'description': "Metaflow empowers data scientists with reproducible workflows, versioned artifacts, and scalable executions on AWS Batch or Kubernetes. While data scientists can request CPU, memory, etc. with the @resources Python decorator, Metaflow doesn't track what's actually tracked at runtime -- leading to overprovisioning, wasted money, or job that crash due to underestimated memory/GPU constraints.\r\n\r\nWe built the @track_resources decorator to address this, which automatically profiles CPU, memory, GPU, VRAM, traffic, storage, and I/O usage at both the process-level and system-wide for each workflow step, whether running locally or in the cloud.\r\n\r\nWith zero-effort and zero dependencies, this tool:\r\n- Auto-generates Metaflow Cards with temporal resource charts, per-instance-type cost projections, and cloud server recommendations.\r\n- Provides actionable insights for optimizing resource allocation.\r\n- Requires just a single line of code to integrate.\r\n\r\nCheck it out on GitHub: https://github.com/SpareCores/resource-tracker",
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'H9DKCZ',
#        'name': 'Gergely Daroczi',
#        'avatar': 'https://cfp.pydata.org/media/avatars/H9DKCZ_igTlFqU.jpg',
#        'biography': 'Gergely Daroczi, PhD, is a passionate R/Python user and package developer for two decades. With over 15 years in the industry, he has expertise in data science, engineering, cloud infrastructure, and data operations across SaaS, fintech, adtech, and healthtech startups in California and Hungary, focusing on building scalable data platforms. Gergely maintains a dozen open-source R and Python projects and organizes a tech meetup with 1,800 members in Hungary – along with other open-source and data conferences.',
#        'public_name': 'Gergely Daroczi',
#        'guid': '84ed02d5-da16-5d9d-89f0-8579b6266fa0',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/H9DKCZ/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/UK7LSY/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/UK7LSY/',
#      'attachments': []}],
#    'Orbit': [{'guid': '07b83481-6cfd-5c53-ba82-94b75e899361',
#      'code': 'YRL7KC',
#      'id': 81753,
#      'logo': None,
#      'date': '2025-09-26T11:05:00+02:00',
#      'start': '11:05',
#      'duration': '00:35',
#      'room': 'Orbit',
#      'slug': 'pydata-amsterdam-2025-81753-data-that-keeps-our-energy-in-balance-from-churn-prediction-with-deep-learning-to-real-time-trading-systems',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/YRL7KC/',
#      'title': 'Data that Keeps Our Energy in Balance - From churn prediction with deep learning to real-time trading systems',
#      'subtitle': '',
#      'track': None,
#      'type': 'Talk',
#      'language': 'en',
#      'abstract': 'This talk explores how data science helps balance energy systems in the face of demand volatility, generation volatility, and the push for sustainability. We’ll dive into two technical case studies: churn prediction using survival models, and the design of a high-availability real-time trading system on Databricks. These examples illustrate how data can support operational resilience and sustainability efforts in the energy sector.',
#      'description': 'Energy may seem simple: pay a provider, receive electricity, not much data involved. But the reality is far more complex. With multiple producers, consumers, and grid operators, and the push for sustainability, balancing energy becomes a challenge in which data plays a big role.\r\nThis talk explores the complexities of the energy sector, focusing on the imbalance problem: energy in must equal energy out on the grid at every single moment. We’ll dive into two areas where data helps Eneco keep the grid stable while supporting society’s shift toward more sustainable energy use:',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'JWYGQN',
#        'name': 'Pablo Estevez',
#        'avatar': 'https://cfp.pydata.org/media/avatars/JWYGQN_gZmVUY4.png',
#        'biography': 'Pablo Estevez leads Data and Machine Learning in Eneco’s Energy Trading teams. For more than ten years he has worked across tech, taking on both hands-on and leadership roles in Machine Learning and Data Science at companies like Booking.com and Meta',
#        'public_name': 'Pablo Estevez',
#        'guid': '2dbd04d9-96da-530a-999b-0f200eb3054b',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/JWYGQN/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/YRL7KC/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/YRL7KC/',
#      'attachments': []},
#     {'guid': '69579012-0cd2-511e-9586-fcc3dc021033',
#      'code': 'EQGKNJ',
#      'id': 77651,
#      'logo': None,
#      'date': '2025-09-26T11:50:00+02:00',
#      'start': '11:50',
#      'duration': '00:35',
#      'room': 'Orbit',
#      'slug': 'pydata-amsterdam-2025-77651-composable-pipelines-for-ml-automating-feature-engineering-with-hopsworks-brewer',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/EQGKNJ/',
#      'title': 'Composable Pipelines for ML: Automating Feature Engineering with Hopsworks’ Brewer',
#      'subtitle': '',
#      'track': None,
#      'type': 'Talk',
#      'language': 'en',
#      'abstract': 'Operationalizing ML isn’t just about models — it’s about moving and engineering data. At Hopsworks, we built a composable AI pipeline builder (Brewer) based on two principles: Tasks and Data Sources. This lets users define workflows that automatically analyse, clean, create and update feature groups, without glue code or brittle scheduling logic.\r\n\r\nIn this talk, we’ll show how Brewer drives the automation of feature engineering, enabling reproducible, declarative pipelines that respond to changes in upstream data. We’ll explore how this fits into broader ML workflows, from ingestion to feature materialization, and how it integrates with warehouses, streams, and file-based systems.',
#      'description': 'We’ll also unpack the real challenges: triggering logic, metadata management, integration with orchestration engines, and maintaining transparency when LLMs are involved. Yes — there will be diagrams and code.\r\n\r\nTopics covered include:\r\n- Tasks and Connectors in feature pipelines\r\n- Automating tables updates\r\n- Integration with existing data stacks\r\n- Architecture + orchestration lessons\r\n- Scaling reproducibility with metadata\r\n\r\nKey takeaways:\r\n- Feature engineering deserves real automation\r\n- LLMs in ML workflows\r\n- Metadata is a first-class citizen\r\n- Clean abstractions beats MCP',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'RUSBZM',
#        'name': 'Javier de la Rúa Martínez',
#        'avatar': 'https://cfp.pydata.org/media/avatars/RUSBZM_KMNK45p.png',
#        'biography': 'Javier is a Research Engineer at Hopsworks, where he actively contributes to advancing the Hopsworks AI Lakehouse. He is currently pursuing his Ph.D. at KTH Royal Institute of Technology in Sweden with a primary focus on large-scale machine learning systems.',
#        'public_name': 'Javier de la Rúa Martínez',
#        'guid': '65c45afd-14d2-509d-b5e2-901653149804',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/RUSBZM/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/EQGKNJ/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/EQGKNJ/',
#      'attachments': []},
#     {'guid': 'b4f9d2fe-4113-5f6a-8521-35d5f8521ed0',
#      'code': 'JDCUMW',
#      'id': 80910,
#      'logo': None,
#      'date': '2025-09-26T13:20:00+02:00',
#      'start': '13:20',
#      'duration': '02:10',
#      'room': 'Orbit',
#      'slug': 'pydata-amsterdam-2025-80910-open-source-sprints-pyiceberg-pymc',
#      'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/JDCUMW/',
#      'title': 'Open source sprints - PyIceberg & PyMC',
#      'subtitle': '',
#      'track': None,
#      'type': 'Sprint',
#      'language': 'en',
#      'abstract': 'Also this year, at our 10 year anniversary edition of PyData Amsterdam, we’ll host open source sprints! ️ Our open source sprints this year will be 2 sessions in parallel, with leading open source contributors Fokko Driesprong and Rob Zinkov of the respective packages PyIceberg and PyMC.',
#      'description': 'What is an open source sprint?\r\nAn open source sprint is an event where programmers come together to make focused contributions to an open source project within a limited timeframe. Participants can work individually or in groups, collaborate directly on coding tasks, fix bugs, and develop new features for the project. The sprint environment offers hands-on coding, mentorship from experienced contributors, and fosters networking and community building among peers. Through time-boxed sessions, programmers can learn from each other, solve problems collaboratively, and quickly advance project goals in a welcoming, supportive setting.\r\n\r\nWhy should you join?\r\n- Gain practical coding experience on real-world projects\r\n- Receive guidance and mentorship from skilled contributors\r\n- Make a meaningful impact on an open source project\r\n- Expand your professional network and meet like-minded peers\r\n- Learn best practices and new technologies in a supportive environment',
#      'recording_license': '',
#      'do_not_record': False,
#      'persons': [{'code': 'PWZQSD',
#        'name': 'Fokko Driesprong',
#        'avatar': 'https://cfp.pydata.org/media/avatars/PWZQSD_Jnp4lbl.png',
#        'biography': "Fokko Driesprong is a Staff Open Source Software Engineer at Databricks. He is an Apache Software Foundation member and serves as a committer and PMC on major Apache projects; Avro, Parquet and Iceberg. He's one of the original authors of PyIceberg, a pure Python library to query Iceberg tables, which has over 400k daily downloads. He studied distributed systems at the University of Groningen and now specializes in building scalable cloud-based data pipelines and analytics solutions.",
#        'public_name': 'Fokko Driesprong',
#        'guid': 'c32aa07c-add4-5503-823c-2620422383f4',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/PWZQSD/'},
#       {'code': 'XPG93D',
#        'name': 'Rob Zinkov',
#        'avatar': 'https://cfp.pydata.org/media/avatars/XPG93D_Yo10XGC.JPG',
#        'biography': 'Rob Zinkov is a machine learning engineer and data scientist. My work covers how to more efficiently specify and train deep generative models as well as how to more effectively discover a good statistical model for your data. I am Principal Data Scientist at PyMC Labs. Previously I was a research scientist at Indiana University where I was the lead developer of the Hakaru probabilistic programming language.',
#        'public_name': 'Rob Zinkov',
#        'guid': '83407c37-b976-54ef-94cc-c01bdddf7023',
#        'url': 'https://cfp.pydata.org/pydata-amsterdam-2025/speaker/XPG93D/'}],
#      'links': [],
#      'feedback_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/JDCUMW/feedback/',
#      'origin_url': 'https://cfp.pydata.org/pydata-amsterdam-2025/talk/JDCUMW/',
#      'attachments': []}]}}]

# %%
schedule = data["schedule"]["conference"]
days = schedule["days"]

# %%
rows = []
desc_map = dict()
speaker_map = dict()

for day in days:
    day_date = day.get("date")  # e.g. "2025-09-24"
    for room_name, events in (day.get("rooms") or {}).items():
        for e in events:
            # Core fields (safe defaults)
            event_id = e.get("id")
            title = normalize_ws(e.get("title", ""))
            talk_type = e.get("type", "")

            start_iso = e.get("date")
            start_dt = parse_iso(start_iso)
            duration = e.get("duration", "00:00")
            dur_min = duration_to_minutes(duration)
            end_dt = (start_dt + timedelta(minutes=dur_min)) if start_dt else None

            speakers_list = [normalize_ws(p.get("public_name", "")) for p in e.get("persons", [])]
            speakers = ", ".join(filter(None, speakers_list))

            # Main CSV row (no bulky text)
            rows.append({
                "day_date": day_date or (start_dt.date().isoformat() if start_dt else ""),
                "start": start_dt.isoformat() if start_dt else "",
                "end": end_dt.isoformat() if end_dt else "",
                "duration_min": dur_min,
                "room": room_name,
                "title": title,
                "type": talk_type,
                "speakers": speakers,
                "event_id": event_id,
            })

            # Description sidecar (JSONL)
            abstract = normalize_ws(e.get("abstract", ""))
            description_html = (e.get("description") or "").strip()
            description_text = normalize_ws(strip_html(unescape(description_html)))

            assert event_id not in desc_map
            desc_map[event_id] = {
                "title": title,
                "speakers": speakers_list,
                "type": talk_type,
                "abstract": abstract,
                "description_text": description_text,
            }

            # --- Speakers mapping (name -> description) -------------------------------
            for p in e.get("persons", []):
                # Prefer public_name; fall back to name
                name = normalize_ws(p.get("public_name") or p.get("name") or "")
                if not name:
                    continue

                # Biography can be plain text, markdown, or HTML; normalize to plain text
                bio_raw = p.get("biography") or ""
                bio_text = normalize_ws(strip_html(unescape(bio_raw)))

                speaker_map[name] = bio_text

# Sort for readability
rows.sort(key=lambda r: (r["day_date"], r["start"], r["room"]))

# ---------- write outputs ----------
fieldnames = [
    "day_date", "start", "end", "duration_min", "room",
    "title", "type", "track", "speakers", "url", "event_id", "guid"
]
with open(out_schedule, "w", encoding="utf-8") as f:
    json.dump(rows, f, indent=2)

with open(out_descriptions, "w", encoding="utf-8") as f:
    json.dump(desc_map, f, indent=2)

# Sort keys for readability
speaker_map_sorted = dict(sorted(speaker_map.items(), key=lambda kv: kv[0].lower()))
with open(out_speakers_description, "w", encoding="utf-8") as f:
    json.dump(speaker_map_sorted, f, ensure_ascii=False, indent=2)

print(f"Wrote {len(rows)} sessions to {out_schedule}")
print(f"Wrote {len(desc_map)} description records to {out_descriptions}")
print(f"Wrote {len(speaker_map)} speaker bios to {out_speakers_description}")
# Out:
# Wrote 61 sessions to data/pydata_amsterdam_2025_schedule.json
# Wrote 61 description records to data/pydata_amsterdam_2025_descriptions.json
# Wrote 82 speaker bios to data/pydata_amsterdam_2025_speakers_description.json
